# %%
import pandas as pd

# %%
# these are the input and output filtered csv files
input_file = "Data/glassdoor_salary_salaries.csv"
output_file = "Data/glassdoor_salary_salaries_filtered.csv"

# %%
# import the salaries file
salaries_df = pd.read_csv(input_file)
# display the imported file
salaries_df
# Out:
#            id  index  salary.salaries.val.basePayCount  \
# 0           1    NaN                               NaN
# 1           2    0.0                               9.0
# 2           2    1.0                               7.0
# 3           2    2.0                               7.0
# 4           2    3.0                               4.0
# ...       ...    ...                               ...
# 408758  35670    0.0                               1.0
# 408759  35670    1.0                               1.0
# 408760  35670    2.0                               1.0
# 408761  35670    3.0                               1.0
# 408762  35670    4.0                               1.0
#
#        salary.salaries.val.jobTitle salary.salaries.val.payPeriod  \
# 0                               NaN                           NaN
# 1               Advanced Consultant                        ANNUAL
# 2                        Consultant                        ANNUAL
# ...

# %%
# these are the columns to keep
keep_columns = [
    'id',
    'index',
    #'salary.salaries.val.basePayCount',
    'salary.salaries.val.jobTitle',
    'salary.salaries.val.payPeriod',
    'salary.salaries.val.salaryPercentileMap.payPercentile10',
    'salary.salaries.val.salaryPercentileMap.payPercentile90',
    'salary.salaries.val.salaryPercentileMap.payPercentile50',
    #'salary.salaries.val.salaryType'
]
# the drop columns will be 
drop_columns =  list(salaries_df.columns)
for keep in keep_columns:
    if (keep in drop_columns):
        drop_columns.remove(keep)
# 
print(f"was {len(list(salaries_df.columns))}, keep {len(keep_columns)}, remove {len(drop_columns)}")
# Out:
# was 9, keep 7, remove 2

# %%
# drop the unwanted columns
salaries_df = salaries_df.drop(drop_columns, axis=1)
# display the data
salaries_df
# Out:
#            id  index salary.salaries.val.jobTitle  \
# 0           1    NaN                          NaN
# 1           2    0.0          Advanced Consultant
# 2           2    1.0                   Consultant
# 3           2    2.0            Software Engineer
# 4           2    3.0              Project Manager
# ...       ...    ...                          ...
# 408758  35670    0.0              Product Manager
# 408759  35670    1.0              Service Manager
# 408760  35670    2.0                          IPC
# 408761  35670    3.0        Applications Engineer
# 408762  35670    4.0                Line Operator
#
#        salary.salaries.val.payPeriod  \
# 0                                NaN
# 1                             ANNUAL
# 2                             ANNUAL
# 3                             ANNUAL
# 4                             ANNUAL
# ...                              ...
# 408758                        ANNUAL
# 408759                        ANNUAL
# ...

# %%
# drop the rows that are empty at the column
salaries_df = salaries_df[salaries_df["index"].notna()]
# format the saleries from float to ints
salaries_df['index'] = salaries_df['index'].astype(int) 
#
salaries_df
# Out:
#            id  index salary.salaries.val.jobTitle  \
# 1           2      0          Advanced Consultant
# 2           2      1                   Consultant
# 3           2      2            Software Engineer
# 4           2      3              Project Manager
# 5           2      4              Lead Consultant
# ...       ...    ...                          ...
# 408758  35670      0              Product Manager
# 408759  35670      1              Service Manager
# 408760  35670      2                          IPC
# 408761  35670      3        Applications Engineer
# 408762  35670      4                Line Operator
#
#        salary.salaries.val.payPeriod  \
# 1                             ANNUAL
# 2                             ANNUAL
# 3                             ANNUAL
# 4                             ANNUAL
# 5                             ANNUAL
# ...                              ...
# 408758                        ANNUAL
# 408759                        ANNUAL
# ...

# %%
# rename the columns to use underscore
columns_rename = list(salaries_df.columns)
for i in range(len(columns_rename)):
    columns_rename[i] = columns_rename[i].replace(".", "_")
    
salaries_df.columns = columns_rename

# %%
salaries_df
# Out:
#            id  index salary_salaries_val_jobTitle  \
# 1           2      0          Advanced Consultant
# 2           2      1                   Consultant
# 3           2      2            Software Engineer
# 4           2      3              Project Manager
# 5           2      4              Lead Consultant
# ...       ...    ...                          ...
# 408758  35670      0              Product Manager
# 408759  35670      1              Service Manager
# 408760  35670      2                          IPC
# 408761  35670      3        Applications Engineer
# 408762  35670      4                Line Operator
#
#        salary_salaries_val_payPeriod  \
# 1                             ANNUAL
# 2                             ANNUAL
# 3                             ANNUAL
# 4                             ANNUAL
# 5                             ANNUAL
# ...                              ...
# 408758                        ANNUAL
# 408759                        ANNUAL
# ...

# %%
# save the csv
salaries_df.to_csv(output_file, index=False)
