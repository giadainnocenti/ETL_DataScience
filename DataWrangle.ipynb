# %%
import pandas as pd
import datetime as dt
import requests

# %%
files = [
    "glassdoor.csv", #!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    #"country_names_2_digit_codes.csv", #----------    
    #"glassdoor_reviews.csv", #--------------------
    #"currency_exchange.csv", #--------------------           
    "glassdoor_salary_salaries.csv", #------------
    #"glassdoor_benefits_highlights.csv", #--------
    #"glassdoor_breadCrumbs.csv"           
]

# %%
dataframes = []
for file in files:
    dataframes.append(pd.read_csv("Data/" + file))

# %%
index = 0
print(files[index])
dataframes[index]
# Out:
# glassdoor.csv
#         benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.000000             2801.0               2801.0
# 1                            4.000000             2802.0               2802.0
# 2                            0.000000             2803.0               2803.0
# 3                            0.000000             2804.0               2804.0
# 4                            0.000000             2805.0               2805.0
# ...                               ...                ...                  ...
# 165285                       0.000000            58396.0              58396.0
# 165286                       3.941176            58397.0              58397.0
# 165287                       0.000000            58398.0              58398.0
# 165288                       0.000000            58399.0              58399.0
# 165289                       0.000000            58400.0              58400.0
#
# ...

# %%
list(dataframes[1].columns)
# Out:
# ['id',
#  'index',
#  'reviews.val.cons',
#  'reviews.val.date',
#  'reviews.val.featured',
#  'reviews.val.helpfulCount',
#  'reviews.val.id',
#  'reviews.val.pros',
#  'reviews.val.publishedOn',
#  'reviews.val.publisher',
#  'reviews.val.reviewRatings.careerOpportunities',
#  'reviews.val.reviewRatings.compBenefits',
#  'reviews.val.reviewRatings.cultureValues',
#  'reviews.val.reviewRatings.overall',
#  'reviews.val.reviewRatings.seniorManagement',
#  'reviews.val.reviewRatings.worklifeBalance',
#  'reviews.val.reviewerDuration',
#  'reviews.val.reviewerInformation',
#  'reviews.val.reviewerJobTitle',
#  'reviews.val.reviewerLocation',
#  'reviews.val.reviewerStatus',
#  'reviews.val.summaryPoints.ceoApproval',
#  'reviews.val.summaryPoints.outlook',
#  'reviews.val.summaryPoints.recommend',
#  'reviews.val.title',
#  'reviews.val.adviceToManagement',
#  'reviews.val.companyResponse',
#  'reviews.val.reviewResponses']

# %%
df = dataframes[1]

# %%
df.all(axis=0, bool_only=None, skipna=True)
# Out:
# id                                                True
# index                                            False
# reviews.val.cons                                  True
# reviews.val.date                                  True
# reviews.val.featured                             False
# reviews.val.helpfulCount                         False
# reviews.val.id                                    True
# reviews.val.pros                                  True
# reviews.val.publishedOn                           True
# reviews.val.publisher                             True
# reviews.val.reviewRatings.careerOpportunities    False
# reviews.val.reviewRatings.compBenefits           False
# reviews.val.reviewRatings.cultureValues          False
# reviews.val.reviewRatings.overall                 True
# reviews.val.reviewRatings.seniorManagement       False
# reviews.val.reviewRatings.worklifeBalance        False
# reviews.val.reviewerDuration                      True
# ...

# %%
# are any values in here null?
df['index'].isnull().values.any()
# Out:
# True

# %%
#working_df = df.dropna(axis=0, how='all', inplace=False)
drop_columns = [
    "index",
    "reviews.val.cons",
    "reviews.val.featured"
]
working_df = df.drop(drop_columns, axis=1)
working_df
# Out:
#             id                                   reviews.val.cons  \
# 0        44001               Still not big enough in market place
# 1        44002                                                NaN
# 2        44003                                                NaN
# 3        44004             Nothing important on my point of view.
# 4        44004  Alot of friends working together which isn't v...
# ...        ...                                                ...
# 422175  116800                   None to mention in this context.
# 422176  116800     Currently no negatives issues to be mentioned.
# 422177  116800  Recruitment:\r\n- Partly uncertainty regarding...
# 422178  116800    - few contact with colleagues on other projects
# 422179  116800                            None identified so far.
#
#        reviews.val.date reviews.val.featured  reviews.val.helpfulCount  \
# 0          Oct 20, 2010                False                       0.0
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_reviews.csv
#             id  index                                   reviews.val.cons  \
# 0        44001    0.0               Still not big enough in market place
# 1        44002    NaN                                                NaN
# 2        44003    NaN                                                NaN
# 3        44004    0.0             Nothing important on my point of view.
# 4        44004    1.0  Alot of friends working together which isn't v...
# ...        ...    ...                                                ...
# 422175  116800    0.0                   None to mention in this context.
# 422176  116800    1.0     Currently no negatives issues to be mentioned.
# 422177  116800    2.0  Recruitment:\r\n- Partly uncertainty regarding...
# 422178  116800    3.0    - few contact with colleagues on other projects
# 422179  116800    4.0                            None identified so far.
#
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# currency_exchange.csv
#     Code                                       Country  \
# 0    AED                    United Arab Emirates (The)
# 1    AFN                                   Afghanistan
# 2    ALL                                       Albania
# 3    AMD                                       Armenia
# 4    ANG                                       Curaçao
# ..   ...                                           ...
# 263  ZMW                                        Zambia
# 264  ZWL                                      Zimbabwe
# 265  NaN                                    Antarctica
# 266  NaN                           Palestine, State Of
# 267  NaN  South Georgia And The South Sandwich Islands
#
#                           Currency  Number  ExchangeRate
# 0                       UAE Dirham   784.0      3.672779
# 1                          Afghani   971.0     78.250197
# 2                              Lek     8.0    111.702860
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_reviews_val_reviewResponses.csv
#          id  index reviews.val.reviewResponses.val.createDate  \
# 0      6762      0                        2018-05-01T03:54:11
# 1      6763      0                        2018-07-17T06:15:22
# 2      6764      0                        2019-01-04T11:48:06
# 3      6765      0                        2018-07-25T12:07:51
# 4      6766      0                        2019-01-16T02:02:05
# ...     ...    ...                                        ...
# 25262  5987      0                        2018-07-17T06:15:22
# 25263  5988      0                        2019-01-04T11:48:06
# 25264  5989      0                        2018-07-25T12:07:51
# 25265  5990      0                        2019-09-16T16:09:36
# 25266  5991      0                        2017-10-06T07:18:03
#
#        reviews.val.reviewResponses.val.helpfulCount  \
# 0                                                 0
# 1                                                 0
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor.csv
#         benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.000000             2801.0               2801.0
# 1                            4.000000             2802.0               2802.0
# 2                            0.000000             2803.0               2803.0
# 3                            0.000000             2804.0               2804.0
# 4                            0.000000             2805.0               2805.0
# ...                               ...                ...                  ...
# 165285                       0.000000            58396.0              58396.0
# 165286                       3.941176            58397.0              58397.0
# 165287                       0.000000            58398.0              58398.0
# 165288                       0.000000            58399.0              58399.0
# 165289                       0.000000            58400.0              58400.0
#
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_salary_salaries.csv
#            id  index  salary.salaries.val.basePayCount  \
# 0           1    NaN                               NaN
# 1           2    0.0                               9.0
# 2           2    1.0                               7.0
# 3           2    2.0                               7.0
# 4           2    3.0                               4.0
# ...       ...    ...                               ...
# 408758  35670    0.0                               1.0
# 408759  35670    1.0                               1.0
# 408760  35670    2.0                               1.0
# 408761  35670    3.0                               1.0
# 408762  35670    4.0                               1.0
#
#        salary.salaries.val.jobTitle salary.salaries.val.payPeriod  \
# 0                               NaN                           NaN
# 1               Advanced Consultant                        ANNUAL
# 2                        Consultant                        ANNUAL
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_benefits_comments.csv
#            id  index benefits.comments.val.city  \
# 0         401    NaN                        NaN
# 1         402    NaN                        NaN
# 2         403    NaN                        NaN
# 3         404    NaN                        NaN
# 4         405    NaN                        NaN
# ...       ...    ...                        ...
# 271431  33598    0.0                     London
# 271432  33599    0.0                    Cwmbran
# 271433  33599    1.0                     Slough
# 271434  33599    2.0                    Cwmbran
# 271435  33600    NaN                        NaN
#
#                             benefits.comments.val.comment  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_wwfu.csv
#          id  index                                      wwfu.val.body  \
# 0       449      0  <p><img class="lazy" style="display: block; ma...
# 1       449      1  <p><iframe style="display: block; margin-left:...
# 2       449      2  <p><img class="lazy" style="display: block; ma...
# 3       449      3  <p><iframe style="display: block; margin-left:...
# 4       449      4  <p style="text-align: center;"><iframe src="ht...
# ...     ...    ...                                                ...
# 86110  3817      0  <h3 style="text-align: center;"><img class="la...
# 86111  3817      1  <h3 style="text-align: left;"><img class="lazy...
# 86112  3817      2  <h3 style="text-align: center;" align="center"...
# 86113  3817      3  <h3 style="text-align: center;" align="center"...
# 86114  3817      4  <h3>DISCOVER OUR UNIQUE OPPORTUNITIES</h3> \n<...
#
#        wwfu.val.id               wwfu.val.title wwfu.val.type  \
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_benefits_highlights.csv
#            id            benefits.highlights.val.highlightPhrase  \
# 0       44001             good flexibility for working from home
# 1       44001  I’ve not really had any time off for the last ...
# 2       44001  Very flexible if you don't work overtime and y...
# 3       44002                                                NaN
# 4       44003                                                NaN
# ...       ...                                                ...
# 212150  39996                                                NaN
# 212151  39997                                                NaN
# 212152  39998                                                NaN
# 212153  39999                                                NaN
# 212154  40000                                                NaN
#
#        benefits.highlights.val.icon benefits.highlights.val.name  index  \
# 0                               wfh               Work From Home    0.0
# ...

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_wwfu_val_captions.csv
#         id  index                              wwfu.val.captions.val
# 0     1407      0                              Our interview process
# 1     1408      0           Andrew Watson | Head of Machine Learning
# 2     1408      1           Connected studio | Singapore Tech Centre
# 3     1409      0           Melloney Luckhurst- UI Designer at Dyson
# 4     1409      1  Dyson UK campus, D9 (left) Lightning Cafe (right)
# ...    ...    ...                                                ...
# 7539  1148      1               Thermo Fisher Job Map United Kingdom
# 7540  1149      0           Our Culture Thermo Fisher United Kingdom
# 7541  1149      1                          Inchinnan 5K Fun Run Team
# 7542  1150      0                           Research and Development
# 7543  1151      0                              Our interview process
#
# [7544 rows x 3 columns]

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_breadCrumbs.csv
#            id  index breadCrumbs.val.name breadCrumbs.val.url
# 0       40801      0                 JOBS      /Job/index.htm
# 1       40802      0                 JOBS      /Job/index.htm
# 2       40803      0                 JOBS      /Job/index.htm
# 3       40804      0                 JOBS      /Job/index.htm
# 4       40805      0                 JOBS      /Job/index.htm
# ...       ...    ...                  ...                 ...
# 165285  32396      0                 JOBS      /Job/index.htm
# 165286  32397      0                 JOBS      /Job/index.htm
# 165287  32398      0                 JOBS      /Job/index.htm
# 165288  32399      0                 JOBS      /Job/index.htm
# 165289  32400      0                 JOBS      /Job/index.htm
#
# [165290 rows x 4 columns]

# %%
index+= 1
print(files[index])
dataframes[index]
# Out:
# glassdoor_wwfu_val_photos.csv
#          id  index                                wwfu.val.photos.val
# 0      2370      0  https://media.glassdoor.com/template/l/40772/f...
# 1      2371      0  https://media.glassdoor.com/template/l/40772/f...
# 2      2372      0  https://media.glassdoor.com/template/l/1162798...
# 3      2373      0  https://media.glassdoor.com/template/l/1162798...
# 4      2374      0  https://media.glassdoor.com/template/l/7774/ta...
# ...     ...    ...                                                ...
# 11431  2016      0  https://media.glassdoor.com/template/l/1737/or...
# 11432  2017      0  https://media.glassdoor.com/template/l/1737/or...
# 11433  2018      0  https://media.glassdoor.com/template/l/6036/am...
# 11434  2019      0  https://media.glassdoor.com/template/l/6036/am...
# 11435  2020      0  https://media.glassdoor.com/template/l/6036/am...
#
# [11436 rows x 3 columns]
