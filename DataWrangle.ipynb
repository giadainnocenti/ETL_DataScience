# %%
import os.path
from os import path
import pandas as pd
import datetime as dt
import requests

# %% [markdown]
# # Data Wrangle! Ye-Haw!
#
# First we need to load in our data
# - glassdoor.csv or (smaller git file)glassdoor_filtered.csv
# - glassdoor_salary_salaries

# %%
# this is the main glassdoor file
glassdoor_file = "Data/glassdoor.csv"
# this is the pre-filtered main gassdoor file, without some columns
# that reduce the file size from 800,00kb, to around 200,00kb
filtered_file = "Data/glassdoor_filtered.csv"
# these are the glassdoor job saleries
salaries_file = "Data/glassdoor_salary_salaries.csv"

# %%
# if the main glassdoor file exists, run the pre-cleanup
if (path.exists(glassdoor_file)):
    # load in the clean_overly_large_columns python script
    # %run -i 'Data/clean_overly_large_columns.py'

# import the filtered_file
glassdoor_df = pd.read_csv(filtered_file)
# set the id column as the index
glassdoor_df.set_index("id", drop=True, inplace=True)
#
glassdoor_df
# Out:
#        index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# id
# 1        NaN                               NaN                          NaN
# 2        0.0                               9.0          Advanced Consultant
# 2        1.0                               7.0                   Consultant
# 2        2.0                               7.0            Software Engineer
# 2        3.0                               4.0              Project Manager
# ...      ...                               ...                          ...
# 35670    0.0                               1.0              Product Manager
# 35670    1.0                               1.0              Service Manager
# 35670    2.0                               1.0                          IPC
# 35670    3.0                               1.0        Applications Engineer
# 35670    4.0                               1.0                Line Operator
#
#       salary.salaries.val.payPeriod  \
# id
# 1                               NaN
# 2                            ANNUAL
# 2                            ANNUAL
# 2                            ANNUAL
# 2                            ANNUAL
# ...                             ...
# 35670                        ANNUAL
# 35670                        ANNUAL
# 35670                        ANNUAL
# 35670                        ANNUAL
# 35670                        ANNUAL
#
#        salary.salaries.val.salaryPercentileMap.payPercentile10  \
# id
# 1                                                    NaN
# 2                                               32257.68
# 2                                               28855.30
# 2                                               30377.86
# 2                                               38254.70
# ...                                                  ...
# 35670                                           34265.47
# 35670                                           51916.31
# 35670                                           31247.73
# 35670                                           47339.83
# 35670                                           18519.93
#
#        salary.salaries.val.salaryPercentileMap.payPercentile90  \
# id
# 1                                                    NaN
# 2                                               41971.34
# 2                                               74022.00
# 2                                               38750.00
# 2                                               48675.67
# ...                                                  ...
# 35670                                           37770.71
# 35670                                           56360.15
# 35670                                           33952.68
# 35670                                           51077.61
# 35670                                           20354.51
#
#        salary.salaries.val.salaryPercentileMap.payPercentile50  \
# id
# 1                                                    NaN
# 2                                               38713.25
# 2                                               38602.20
# 2                                               35032.53
# 2                                               45636.77
# ...                                                  ...
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
#
#       salary.salaries.val.salaryType
# id
# 1                                NaN
# 2                           employer
# 2                           employer
# 2                           employer
# 2                           employer
# ...                              ...
# 35670                       employer
# 35670                       employer
# 35670                       employer
# 35670                       employer
# 35670                       employer
#
# [408763 rows x 8 columns]

# %%
# import the salaries_file
salaries_df = pd.read_csv(salaries_file)
# set the id column as the index
salaries_df.set_index("id", drop=True, inplace=True)
#
salaries_df
# Out:
#        index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# id
# 1        NaN                               NaN                          NaN
# 2        0.0                               9.0          Advanced Consultant
# 2        1.0                               7.0                   Consultant
# 2        2.0                               7.0            Software Engineer
# 2        3.0                               4.0              Project Manager
# ...      ...                               ...                          ...
# 35670    0.0                               1.0              Product Manager
# 35670    1.0                               1.0              Service Manager
# 35670    2.0                               1.0                          IPC
# 35670    3.0                               1.0        Applications Engineer
# 35670    4.0                               1.0                Line Operator
#
#       salary.salaries.val.payPeriod  \
# id
# 1                               NaN
# 2                            ANNUAL
# 2                            ANNUAL
# 2                            ANNUAL
# 2                            ANNUAL
# ...                             ...
# 35670                        ANNUAL
# 35670                        ANNUAL
# 35670                        ANNUAL
# 35670                        ANNUAL
# 35670                        ANNUAL
#
#        salary.salaries.val.salaryPercentileMap.payPercentile10  \
# id
# 1                                                    NaN
# 2                                               32257.68
# 2                                               28855.30
# 2                                               30377.86
# 2                                               38254.70
# ...                                                  ...
# 35670                                           34265.47
# 35670                                           51916.31
# 35670                                           31247.73
# 35670                                           47339.83
# 35670                                           18519.93
#
#        salary.salaries.val.salaryPercentileMap.payPercentile90  \
# id
# 1                                                    NaN
# 2                                               41971.34
# 2                                               74022.00
# 2                                               38750.00
# 2                                               48675.67
# ...                                                  ...
# 35670                                           37770.71
# 35670                                           56360.15
# 35670                                           33952.68
# 35670                                           51077.61
# 35670                                           20354.51
#
#        salary.salaries.val.salaryPercentileMap.payPercentile50  \
# id
# 1                                                    NaN
# 2                                               38713.25
# 2                                               38602.20
# 2                                               35032.53
# 2                                               45636.77
# ...                                                  ...
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
#
#       salary.salaries.val.salaryType
# id
# 1                                NaN
# 2                           employer
# 2                           employer
# 2                           employer
# 2                           employer
# ...                              ...
# 35670                       employer
# 35670                       employer
# 35670                       employer
# 35670                       employer
# 35670                       employer
#
# [408763 rows x 8 columns]

# %% [markdown]
# ## Drop it like it's hot!
# Now we will drop all the data that we believe can be removed for the scope of this project

# %%
drop_columns = [
    "index",
    "reviews.val.cons",
    "reviews.val.featured"
]
working_df = df.drop(drop_columns, axis=1)
working_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-a691d5c531cd> in <module>
#       4     "reviews.val.featured"
#       5 ]
# ----> 6 working_df = df.drop(drop_columns, axis=1)
#       7 working_df
#
# NameError: name 'df' is not defined
