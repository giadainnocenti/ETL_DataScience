# %%
import os.path
from os import path
import pandas as pd

# %% [markdown]
# # Data Wrangle! Ye-Haw!
#
# First we need to load in our data
# - glassdoor_filtered.csv
# - glassdoor_salary_salaries_filtered.csv

# %%
# this is the pre-filtered main gassdoor file, without some columns
filtered_file = "Data/glassdoor_filtered.csv"
# these are the glassdoor job saleries
salaries_file = "Data/glassdoor_salary_salaries_filtered.csv"

# %%
# import the filtered_file
glassdoor_df = pd.read_csv(filtered_file)
# set the id column as the index
glassdoor_df
#
glassdoor_df
# Out:
#         gaTrackerData.empId               gaTrackerData.empName  \
# 0                   1382539                               Xfers
# 1                      7448                        Altran Group
# 2                   1727201                            Moneybox
# 3                    354093                              Demant
# 4                    642590                          OutSystems
# ...                     ...                                 ...
# 147144              1013251                               Canva
# 147145               722741         Mitra Integrasi Informatika
# 147146               931298                         Haufe Group
# 147147              3082694                 Profile Middle East
# 147148               231682  Northern NSW Local Health District
#
#        gaTrackerData.empSize                   gaTrackerData.industry  \
# 0                       1-50         Financial Transaction Processing
# 1                   10000--1                              IT Services
# 2                       1-50                                      NaN
# 3                   10000--1         Health Care Services & Hospitals
# 4                  1001-5000             Computer Hardware & Software
# ...                      ...                                      ...
# 147144               201-500             Computer Hardware & Software
# 147145              501-1000                               Accounting
# 147146             1001-5000  Enterprise Software & Network Solutions
# 147147                  -1-0                                      NaN
# 147148            5001-10000         Health Care Services & Hospitals
#
#         gaTrackerData.industryId  gaTrackerData.jobId.long  \
# 0                         200052              3.281584e+09
# 1                         200064              3.357106e+09
# 2                              0              3.386690e+09
# 3                         200059              3.401994e+09
# 4                         200060              3.036655e+09
# ...                          ...                       ...
# 147144                    200060              3.258735e+09
# 147145                    200001              3.327617e+09
# 147146                    200061              3.412664e+09
# 147147                         0              3.238053e+09
# 147148                    200059              3.395580e+09
#
#         gaTrackerData.jobId.int  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 147144                      NaN
# 147145                      NaN
# 147146                      NaN
# 147147                      NaN
# 147148                      NaN
#
#                                    gaTrackerData.jobTitle  \
# 0             Software Engineer, Full Stack - HCM Vietnam
# 1                       Android Automotive Engineer (W/M)
# 2                                         Product Manager
# 3                                        Business Analyst
# 4                   Software Engineer Team Leader - Braga
# ...                                                   ...
# 147144                   Senior Product Marketing Manager
# 147145                              Functional Consultant
# 147146                    Technical Product Owner (m/w/d)
# 147147                        Warehouse/Material Engineer
# 147148  Medical Laboratory Assistant - Pathology Colle...
#
#        gaTrackerData.location  gaTrackerData.locationId  ...  \
# 0                         NaN                   2748023  ...
# 1                         NaN                   2457577  ...
# 2                      London                   2671300  ...
# 3                         NaN                   3008741  ...
# 4                       Braga                   3227540  ...
# ...                       ...                       ...  ...
# 147144                    NaN                   2235932  ...
# 147145                Jakarta                   2709872  ...
# 147146               Freiburg                   2566280  ...
# 147147                Sharjah                   2203109  ...
# 147148                    NaN                   2240788  ...
#
#        salary.currency.defaultFractionDigits  salary.currency.displayName  \
# 0                                        NaN                          NaN
# 1                                        2.0   United Kingdom Pound (GBP)
# 2                                        2.0   United Kingdom Pound (GBP)
# 3                                        NaN                          NaN
# 4                                        2.0   United Kingdom Pound (GBP)
# ...                                      ...                          ...
# 147144                                   NaN                          NaN
# 147145                                   NaN                          NaN
# 147146                                   NaN                          NaN
# 147147                                   NaN                          NaN
# 147148                                   NaN                          NaN
#
#        salary.currency.id  salary.currency.name  \
# 0                     NaN                   NaN
# 1                     2.0  United Kingdom Pound
# 2                     2.0  United Kingdom Pound
# 3                     NaN                   NaN
# 4                     2.0  United Kingdom Pound
# ...                   ...                   ...
# 147144                NaN                   NaN
# 147145                NaN                   NaN
# 147146                NaN                   NaN
# 147147                NaN                   NaN
# 147148                NaN                   NaN
#
#        salary.currency.negativeTemplate salary.currency.new  \
# 0                                   NaN                 NaN
# 1                                  $(#)               False
# 2                                  $(#)               False
# 3                                   NaN                 NaN
# 4                                  $(#)               False
# ...                                 ...                 ...
# 147144                              NaN                 NaN
# 147145                              NaN                 NaN
# 147146                              NaN                 NaN
# 147147                              NaN                 NaN
# 147148                              NaN                 NaN
#
#        salary.currency.positiveTemplate salary.currency.symbol  \
# 0                                   NaN                    NaN
# 1                                    $#                &pound;
# 2                                    $#                &pound;
# 3                                   NaN                    NaN
# 4                                    $#                &pound;
# ...                                 ...                    ...
# 147144                              NaN                    NaN
# 147145                              NaN                    NaN
# 147146                              NaN                    NaN
# 147147                              NaN                    NaN
# 147148                              NaN                    NaN
#
#         salary.lastSalaryDate salary.salaries
# 0                         NaN             1.0
# 1         2019-09-30T12:23:30             2.0
# 2         2019-11-02T07:01:49             3.0
# 3                         NaN             4.0
# 4         2019-09-24T12:04:04             5.0
# ...                       ...             ...
# 147144                    NaN        147145.0
# 147145                    NaN        147146.0
# 147146                    NaN        147147.0
# 147147                    NaN        147148.0
# 147148                    NaN        147149.0
#
# [147149 rows x 57 columns]

# %%
# import the salaries_file
salaries_df = pd.read_csv(salaries_file)
# set the id column as the index
salaries_df.set_index("id", drop=True, inplace=True)
#
salaries_df
# Out:
#        index salary.salaries.val.jobTitle salary.salaries.val.payPeriod  \
# id
# 1        NaN                          NaN                           NaN
# 2        0.0          Advanced Consultant                        ANNUAL
# 2        1.0                   Consultant                        ANNUAL
# 2        2.0            Software Engineer                        ANNUAL
# 2        3.0              Project Manager                        ANNUAL
# ...      ...                          ...                           ...
# 35670    0.0              Product Manager                        ANNUAL
# 35670    1.0              Service Manager                        ANNUAL
# 35670    2.0                          IPC                        ANNUAL
# 35670    3.0        Applications Engineer                        ANNUAL
# 35670    4.0                Line Operator                        ANNUAL
#
#        salary.salaries.val.salaryPercentileMap.payPercentile10  \
# id
# 1                                                    NaN
# 2                                               32257.68
# 2                                               28855.30
# 2                                               30377.86
# 2                                               38254.70
# ...                                                  ...
# 35670                                           34265.47
# 35670                                           51916.31
# 35670                                           31247.73
# 35670                                           47339.83
# 35670                                           18519.93
#
#        salary.salaries.val.salaryPercentileMap.payPercentile90  \
# id
# 1                                                    NaN
# 2                                               41971.34
# 2                                               74022.00
# 2                                               38750.00
# 2                                               48675.67
# ...                                                  ...
# 35670                                           37770.71
# 35670                                           56360.15
# 35670                                           33952.68
# 35670                                           51077.61
# 35670                                           20354.51
#
#        salary.salaries.val.salaryPercentileMap.payPercentile50
# id
# 1                                                    NaN
# 2                                               38713.25
# 2                                               38602.20
# 2                                               35032.53
# 2                                               45636.77
# ...                                                  ...
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
# 35670                                                NaN
#
# [408763 rows x 6 columns]
